# %%
features_2013 = {
            "S.NO" : "Serial no",
            "ST" : "States/UTs",
            "AR"  : "Rural area in square kms",
            "AU"  : "Urban area in square kms",
            "ATT" : "Total area",
            "P_R" : "Rural percentage",
            "N_D" : "Number of districts",
            "N_V" : "Number of villages",
    
            "POR_2001" : "Rural population (2001)",
            "POU_2001" : "Urban popuation (2001)",
            "POT_2001" : "Total population 2001",
            "RUR_Per_2001" : "Rural percentage 2001",
            "POR_2011" : "Rural population (2011)",
            "POU_2011" : "Urban popuation (2011)",
            "POT_2011" : "Total population 2011",
            "RUR_Per_2011" : "Rural percentage 2011",
    
            "DPGR" : "Decadal populaton growth rate(2001 -2011)",
            "PD11"   : "Population Density per square kms (2011)",
    
            "DPGR_R" : "Decennial populaton growth rate(2001 -2011) for rural areas",
            "DPGR_U" : "Decennial populaton growth rate(2001 -2011) for urban areas",
            "DPGR_T" : "Total Decennial populaton growth rate(2001 -2011)",
            "PD19_R" : "Rural Population density per square kms (2001)",
            "PD19_U" : "Urban Population density per square kms (2001)",
            "PD19_T" : "Total Population density per square kms (2001)",
    
            "CBR_T" : "Total Crude Birth rate (2012)",
            "CBR_R" : "Crude Birth rate Rural (2012)",
            "CBR_U" : "Crude Birth rate Urban (2012)",
            "CDR_T" : "Total Crude Death rate (2012)",
            "CDR_R" : "Crude Death rate Rural (2012)",
            "CDR_U" : "Crude Death rate Urban (2012)",
    
            "IMR_T" : "Total Infant Mortality Rate (2012)",
            "IMR_R" : "Infant Mortality Rate Rural (2012)",
            "IMR_U" : "Infant Mortality Rate Urban (2012)",
    
            "NSC_FIVEYEAR_6" : "Number of Sub centers functioning at the end of Sixth Plan (1981-85)",
            "NSC_FIVEYEAR_7" : "Number of Sub centers functioning at the end of Seventh Plan (1985-90)",
            "NSC_FIVEYEAR_8" : "Number of Sub centers functioning at the end of Eighth Plan (1992-97)",
            "NSC_FIVEYEAR_9" : "Number of Sub centers functioning at the end of Ninth Plan (1997-2002)",
            "NSC_FIVEYEAR_10" : "Number of Sub centers functioning at the end of Tenth Plan (2002-2007)",
            "NSC_FIVEYEAR_11" : "Number of Sub centers functioning at the end of Eleventh Plan (2007-2012)",
            "NSC_FIVEYEAR_12" : "Number of Sub centers functioning at the end of Twelth Plan (2012-2017)",
    
            "NPHC_FIVEYEAR_6" : "Number of Primary Health Centers functioning at the end of Sixth Plan (1981-85)",
            "NPHC_FIVEYEAR_7" : "Number of Primary Health Centers functioning at the end of Seventh Plan (1985-90)",
            "NPHC_FIVEYEAR_8" : "Number of Primary Health Centers functioning at the end of Eighth Plan (1992-97)",
            "NPHC_FIVEYEAR_9" : "Number of Primary Health Centers functioning at the end of Ninth Plan (1997-2002)",
            "NPHC_FIVEYEAR_10" : "Number of Primary Health Centers functioning at the end of Tenth Plan (2002-2007)",
            "NPHC_FIVEYEAR_11" : "Number of Primary Health Centers functioning at the end of Eleventh Plan (2007-2012)",
            "NPHC_FIVEYEAR_12" : "Number of Primary Health Centers functioning at the end of Twelth Plan (2012-2017)",
    
            "NCHC_FIVEYEAR_6" : "Number of Community Health Centers functioning at the end of Sixth Plan (1981-85)",
            "NCHC_FIVEYEAR_7" : "Number of Community Health Centers functioning at the end of Seventh Plan (1985-90)",
            "NCHC_FIVEYEAR_8" : "Number of Community Health Centers functioning at the end of Eighth Plan (1992-97)",
            "NCHC_FIVEYEAR_9" : "Number of Community Health Centers functioning at the end of Ninth Plan (1997-2002)",
            "NCHC_FIVEYEAR_10" : "Number of Community Health Centers functioning at the end of Tenth Plan (2002-2007)",
            "NCHC_FIVEYEAR_11" : "Number of Community Health Centers functioning at the end of Eleventh Plan (2007-2012)",
            "NCHC_FIVEYEAR_12" : "Number of Community Health Centers functioning at the end of Twelth Plan (2012-2017)",
    
                
            "F_SC" : "Number of functional Sub centers",
            "F_PHC": "Number of functional PHCs",
            "F_CHC": "Number of functional CHCs",
    
            "F_SDH" : "Number of functional Sub Divisional Hospital",
            "F_DH" : "Number of District Hospital",
            "F_MMU" : "Number of functioning Mobile Medical Units",
    
            "POT_R" :  "Tribal population in Rural Areas",
            "R_SC" : "Required SCs",
            "P_SC" : "In position SCs",
            "SH_SC" : "Shortfall in SCs",
            "SH_SC_P" : "Percent shortfall in SCs",
            
            "R_PHC" : "Required PHCs",
            "P_PHC" : "In position PHCs",
            "SH_PHC" : "Shortfall in PHCs",
            "SH_PHC_P" : "Percent shortfall in PHCs",
            
            "R_CHC" : "Required CHCs",
            "P_CHC" : "In position CHCs",
            "SH_CHC" : "Shortfall in CHCs",
            "SH_CHC_P" : "Percent shortfall in CHCs",
    
            "SC_GB": "SCs functioning in Govt. Buildings.",
            "SC_RB": "SCs functioning in Rented Buildings",
            "SC_RFP": "SCs functioning in Rent Free Panchayat/ Vol. Society Buildings",
            "SC_BUC": "SCs Buildings Under Construction",
            "SC_BRC": "SCs Buildings required to be constructed",
    
            "PHC_GB": "PHCs functioning in Govt. Buildings",
            "PHC_RB": "PHCs functioning in Rented Buildings",
            "PHC_RFP": "PHCs functioning in Rent Free Panchayat/ Vol. Society Buildings",
            "PHC_BUC": "PHCs Buildings Under Construction",
            "PHC_BRC": "PHCs Buildings required to be constructed",
    
            "CHC_GB": "CHCs functioning in Govt. Buildings",
            "CHC_RB": "CHCs functioning in Rented Buildings",
            "CHC_RFP": "CHCs functioning in Rent Free Panchayat/ Vol. Society Buildings",
            "CHC_BUC": "CHCs functioning in Buildings Under Construction",
            "CHC_BRC": "CHCs functioning in Buildings required to be constructed",
            
            "HWF_ANM_SC_R" : "Required Health worker female per ANM at SC",
            "HWF_ANM_SC_S" : "Sanctioned Health worker female per ANM at SC",
            "HWF_ANM_SC_P" : "In position Health worker female per ANM at SC",
            "HWF_ANM_SC_V" : "Vacant Health worker female per ANM at SC",
            "HWF_ANM_SC_SH" : "Shortfall Health worker female per ANM at SC",
    
            "HWF_ANM_SC_PHC_R" : "Required Health worker female per ANM at SC and PHCs",
            "HWF_ANM_SC_PHC_S" : "Sanctioned Health worker female per ANM at SC and PHCs",
            "HWF_ANM_SC_PHC_P" : "In position Health worker female per ANM at SC and PHCs",
            "HWF_ANM_SC_PHC_V" : "Vacant Health worker female per ANM at SC and PHCs",
            "HWF_ANM_SC_PHC_SH" : "Shortfall Health worker female per ANM at SC and PHCs",
    
            "HWM_SC_R" : "Required Health worker male at SC",
            "HWM_SC_S" : "Sanctioned Health worker male at SC",
            "HWM_SC_P" : "In position Health worker male at SC",
            "HWM_SC_V" : "Vacant Health worker male at SC",
            "HWM_SC_SH" : "Shortfall Health worker male at SC",
            
            "SC_WO_HWF_ANM" : "Sub-centers without Health worker females per ANM",
            "SC_WO_HWM" : "Sub-centers without Health workers male",
            "SC_WO_HWF_HWM" : "Sub-centers without HWF and HWM",
    
            "HAF_LHV_PHC_R" : "Required Health Assistants female LHV at PHCs",
            "HAF_LHV_PHC_S" : "Sanctioned Health Assistants female LHV at PHCs",
            "HAF_LHV_PHC_P" : "In position Health Assistants female LHV at PHCs",
            "HAF_LHV_PHC_V" : "Vacant Health Assistants female LHV at PHCs",
            "HAF_LHV_PHC_SH" : "Shortfall Health Assistants female LHV at PHCs",
            
            "HAM_PHC_R" : "Required Health Assistants Male at PHCs",
            "HAM_PHC_S" : "Sanctioned Health Assistants Male at PHCs",
            "HAM_PHC_P" : "In position Health Assistants Male at PHCs",
            "HAM_PHC_V" : "Vacant Health Assistants Male at PHCs",
            "HAM_PHC_SH" : "Shortfall Health Assistants Male at PHCs",
    
            "DOC_PHC_R" : "Required Doctors at PHCs",
            "DOC_PHC_S" : "Sanctioned Doctors at PHCs",
            "DOC_PHC_P" : "In Position Doctors at PHCs",
            "DOC_PHC_V" : "Vacant Doctors at PHCs",
            "DOC_PHC_SH" : "Shortfall Doctors at PHCs",
    
            "PHC_W_4PLUS_DOC" : "Number of PHCs with 4 plus doctors",
            "PHC_W_3PLUS_DOC" : "Number of PHCs with 3 plus doctors",
            "PHC_W_2PLUS_DOC" : "Number of PHCs with 2 plus doctors",
            "PHC_W_1PLUS_DOC" : "Number of PHCs with 1 plus doctors",
            "PHC_WO_DOC" : "Number of PHCs without Doctor",
            "PHC_WO_LT" : "Number of PHCs without lab tech",
            "PHC_WO_PHARMA" : "Number of PHCs without pharma",
            "PHC_W_LAD" : "Number of PHCs with lady doctor",
            
    
            "PHC_AYUSH" : "Number of PHCs with AYUSH facility",

    
            "SUR_CHC_R": "Required Surgeons at CHCs",
            "SUR_CHC_S": "Sanctioned Surgeons at CHCs",
            "SUR_CHC_P": "In position Surgeons at CHCs",
            "SUR_CHC_V": "Vacant Surgeons at CHCs",
            "SUR_CHC_SH": "Shorfall Surgeons at CHCs",
    
    
            "OBGY_CHC_R": "Required OBGYs at CHCs",
            "OBGY_CHC_S": "Sanctioned OBGYs at CHCs",
            "OBGY_CHC_P": "In position OBGYs at CHCs",
            "OBGY_CHC_V": "Vacant OBGYs at CHCs",
            "OBGY_CHC_SH": "Shortfall OBGYs at CHCs",
    
            "PHY_CHC_R" : "Required Physicians at CHCs",
            "PHY_CHC_S" : "Sanctioned Physicians at CHCs",
            "PHY_CHC_P" : "In position Physicians at CHCs",
            "PHY_CHC_V" : "Vacant Physicians at CHCs",
            "PHY_CHC_SH" : "Shortfall Physicians at CHCs",
    
            "PAED_CHC_R": "Required Paediatricians at CHCs",
            "PAED_CHC_S": "Sanctioned Paediatricians at CHCs",
            "PAED_CHC_P": "In position Paediatricians at CHCs",
            "PAED_CHC_V": "Vacant Paediatricians at CHCs",
            "PAED_CHC_SH": "Shortfall Paediatricians at CHCs",
    
            "TSP_CHC_R": "Required total specialists at CHCs",
            "TSP_CHC_S": "Sanctioned total specialists at CHCs",
            "TSP_CHC_P": "In position total specialists at CHCs",
            "TSP_CHC_V": "Vacant total specialists at CHCs",
            "TSP_CHC_SH": "Shortfall total specialists at CHCs",
    
            "GDMO_AL_CHC_S": "Sanctioned GDMO Allopathic at CHCs",
            "GDMO_AL_CHC_P": "In Position GDMO Allopathic at CHCs",
    
            "RAD_CHC_R": "Required Radiographers at CHCs",
            "RAD_CHC_S": "Sanctioned Radiographers at CHCs",
            "RAD_CHC_P": "In position Radiographers at CHCs",
            "RAD_CHC_V": "Vacant Radiographers at CHCs",
            "RAD_CHC_SH": "Shortfall Radiographers at CHCs",
    
            "PHARMA_PHC_CHC_R": "Required Pharmacists at PHCs and CHCs",
            "PHARMA_PHC_CHC_S": "Sanctioned Pharmacists at PHCs and CHCs",
            "PHARMA_PHC_CHC_P": "In Position Pharmacists at PHCs and CHCs",
            "PHARMA_PHC_CHC_V": "Vacant Pharmacists at PHCs and CHCs",
            "PHARMA_PHC_CHC_SH": "Shortfall Pharmacists at PHCs and CHCs",
    
            "LT_PHC_CHC_R": "Required Lab technicians at PHCs and CHCs",
            "LT_PHC_CHC_S": "Sanctioned Lab technicians at PHCs and CHCs",
            "LT_PHC_CHC_P": "In Position Lab technicians at PHCs and CHCs",
            "LT_PHC_CHC_V": "Vacant Lab technicians at rural PHCs and CHCs",
            "LT_PHC_CHC_SH": "Shortfall Lab technicians at PHCs and CHCs",

            "NURSE_PHC_CHC_R" : "Required nursing staff at PHCs and CHCs",
            "NURSE_PHC_CHC_S" : "Sanctioned nursing staff at PHCs and CHCs",
            "NURSE_PHC_CHC_P" : "In Position nursing staff at PHCs and CHCs",
            "NURSE_PHC_CHC_V" : "Vacant nursing staff at PHCs and CHCs",
            "NURSE_PHC_CHC_SH" : "Shortfall nursing staff at PHCs and CHCs",
    
            "BEE_PHC_S" : "Sanctioned Block Extention Educators at PHCs",
            "BEE_PHC_P" : "In position Block Extention Educators at PHCs",          
            "BEE_PHC_V" : "Vacant Block Extention Educators at PHCs",
    
            "ANM_SC_PHC" : "Number of ANMs(SCs and PHCs)",
            "V_HWM" : "Vacancy of HWMs",
            "V_HAF_LHV" : "Vacancy of HAF per LHV",
            "V_HAM" : "Vacany of HAM",
            "V_MO_PHC" : "Vacancy of Medical Officer at PHCs",
            "V_SPEC_CHC" : "Vacancy of Specialists at CHCs",
    
            "ANM_SC_N" : "Number of  Sub Centers with ANM Quarter",
            "ANM_SC_P" : "Percentage of  Sub Centers with ANM Quarter",
            "ANM_L_SC_N" : "Number of  Sub Centers with ANM living in SC Quarter",
            "ANM_L_SC_P" : "Percentage of  Sub Centers with ANM living in SC Quarter",
            "F_SC_IPHS" : "Number of functioning  SCs as per IPHS norms",
    
            "SC_WO_RWS_N" : "Number of SCs without Regular Water Supply",
            "SC_WO_RWS_P" : "Percentage of SCs without Regular Water Supply",
            "SC_WO_ES_N" : "Number of SCs without Electric Supply",
            "SC_WO_ES_P" : "Percentage of SCs without Electric Supply",
            "SC_WO_MAR_N" : "Number of SCs without All-Weather Motorable Approach Road",
            "SC_WO_MAR_P" : "Percentage of SCs without All-Weather Motorable Approach Road",
    
                
            "PHC_W_LR_N" : "Number of PHC with Labour Room",
            "PHC_W_LR_P" : "Percentage of PHC with Labour Room",
            "PHC_W_OT_N" : "Number of PHC with OT",
            "PHC_W_OT_P" : "Percentage of PHC with OT",
            "PHC_W_4BED_N" : "Number of PHC with at least 4 beds",
            "PHC_W_4BED_P" : "Percentage of PHC with at least 4 beds",
    
            
            "PHC_WO_ES_N" : "Number of PHCs without Electric Supply",
            "PHC_WO_ES_P" : "Percentage of PHCs without Electric Supply",
            "PHC_WO_RWS_N" : "Number of PHCs without Regular Water Supply",
            "PHC_WO_RWS_P" : "Percentage of PHCs without Regular Water Supply",
            "PHC_WO_MAR_N" : "Number of PHCs without All-Weather Motorable Approach Road",
            "PHC_WO_MAR_P" : "Percentage of PHCs without All-Weather Motorable Approach Road",
            "PHC_W_TEL_N" : "Number of PHCs with Telephone",
            "PHC_W_TEL_P" : "Percentage of PHCs with Telephone",
            "PHC_W_COMP_N" : "Number of PHCs with Computer",
            "PHC_W_COMP_P" : "Percentage of PHCs with Computer",
    
            "PHC_W_RT" : "Number of PHCs with referral transport available",
            "PHC_W_RRKS" : "Number of PHCs with registered RKS",
            "F_PHC_IPHS" : "Number of functioning  PHCs as per IPHS norms",
    
    
            "CHC_W_AFS" : "Number of CHCs with all four specialists",
            "CHC_W_CSA": "Numberof CHCs With computer/ Statistical Asst. for MIS/ Accountant",
            "CHC_W_FL" : "Number of CHCs with Functional Laboratory",
            "CHC_W_FOT" : "Number of CHCs with Functional OT",
            "CHC_W_FLR" : "Number of CHCs with Functional Labour Room",
            "CHC_W_FSUNB" : "Number of CHCs with Functioning Stabilization Units for New Born",
            "CHC_W_NBCC" : "Number of CHCs with New Born Care Corner",
            "CHC_W_30BED" : "Number of CHCs with at least 30 beds",
        
    
            "CHC_W_FXRAY" : "Number of CHCs with Functional X-Ray machine",
            "CHC_W_QSD" : "Number of CHCs with quarters for specialist doctors",
            "CHC_W_SDLQ": "Number of CHCs with specialist doctors living in quarters",
            "CHC_W_RT" : "Number of CHCs with referral transport available",
            "CHC_W_RRKS" : "Number of CHCs with registered RKS",
            "F_CHC_IPHS" : "Number of functioning CHCs as per IPHS norms",
            "CHC_RS_ALO" : "Number of CHCs having a regular supply of Allopathic drugs for common ailments",
            "CHC_RS_AYUSH" : "Number of CHCs having a regular supply of AYUSH drugs for common ailments",
    
            "TS_ANM_HW" : "Number of Training schools ANM/HW[F]",
            "TS_LHV_HA" : "Number of Training Schools LHV/HA[F]",
    
            "HFWTC" : "Health and Family Welfare Training Centres",
            "MPW_M" : "MPW(M) Training Schools",
    
            "POP_COV_SC_SC" : "Population Coverage (range) SCs",
            "NO_ST_UT_SC_SC": "Number of States/UTs SCs",
            "POP_COV_NAME_SC" : "Name of states SCs",
            "AVG_RPC_SC": "Average Rural Population covered [Census 2011] by SCs",
    
            "POP_COV_PHC" : "Population Coverage (range) PHCs",
            "NO_ST_UT_PHC": "Number of States/UTs PHCs",
            "POP_COV_NAME_PHC" : "Name of states PHCs",
            "AVG_RPC_PHC" : "Average Rural Population covered [Census 2011] by PHCs",
    
            
            "POP_COV_CHC" : "Population Coverage (range) CHC",
            "NO_ST_UT_CHC": "Number of States/UTs CHC",
            "POP_COV_NAME_CHC" : "Name of states CHC",
            "AVG_RPC_CHC" : "Average Rural Population covered [Census 2011] by CHCs",
    
            "N_AVG_RPC_SC" : "Average Rural Population [Census 2011] covered by a SC",
            "N_AVG_RPC_PHC" : "Average Rural Population [Census 2011] covered by a PHC",
            "N_AVG_RPC_CHC" : "Average Rural Population [Census 2011] covered by a CHC",
    
            
            "AVG_RA_SC" : "Average Rural Area [Sq. Km.] covered by a SC",
            "AVG_RA_PHC" : "Average Rural Area [Sq. Km.] covered by a PHC",
            "AVG_RA_CHC" : "Average Rural Area [Sq. Km.] covered by a CHC",
    
            "AVG_RD_SC" : "Average Radial Distance [Kms] covered by a SC",
            "AVG_RD_PHC" : "Average Radial Distance [Kms] covered by a PHC",
            "AVG_RD_CHC" : "Average Radial Distance [Kms] covered by a CHC",
    
            "AVG_VC_SC" : "Average Number of Villages covered by a SC",
            "AVG_VC_PHC" : "Average Number of Villages covered by a PHC",
            "AVG_VC_CHC" : "Average Number of Villages covered by a CHC",
            "SC_TO_PHC" : "Number of SCs per PHCs",
            "PHC_TO_CHC": "Number of PHCs  per CHC",
    
            "ANM_TO_LHV" : "Ratio of ANM Schools per LHV School",
            "RP_ANM" : "Rural population (2011) [in lakhs] covered by a ANM school",
            "RP_LHV" : "Rural population (2011) [in lakhs] covered by a LHV school",
    
            "HWM_SC" : "In position HW[M] in SC",
            "HAM_SC" : "In position HA[M] in SC",
            "HWM_TO_HAM_SC" : "Number of HW[M] per HA[M] in SC",
            "AVG_RPC_HWM_SC" : "Average Rural Population [census 2011] covered by an HW[M] in SC",
    
            "HWF_ANM_SC_PHC" : "In position HW[F]/ ANM at rural SC and PHCs",
            "HAF_LHV_SC_PHC" : "In Position HA[F]/ LHV at rural SC and PHCs",
            "HWF_ANM_TO_HAF_LHV_SC_PHC" : "Number of HW [F]/ ANM per HA [F]/ LHV at rural SC and PHCs",
            "AVG_RPC_HWF_ANM_SC_PHC" : "Average Rural Population [Census 2011] covered by an  HW[F]/ ANM at rural SC and PHCs",

            "SC_T_R" : "Required tribal SCs",
            "SC_T_P" : "In position tribal SCs",
            "SC_T_SH" : "Shortfall in tribal SCs",
            "PHC_T_R" : "Required tribal PHCs",
            "PHC_T_P" : "In position tribal PHCs",
            "PHC_T_SH" : "Shortfall in tribal PHCs",
            "CHC_T_R" : "Required tribal CHCs",
            "CHC_T_P" : "In position tribal CHCs",
            "CHC_T_SH" : "Shortfall in tribal CHCs",
    
            "SC_T_GB": "Tribal SCs functioning in Govt. Buildings.",
            "SC_T_RB": "Tribal SCs functioning in Rented Buildings",
            "SC_T_RFP": "Tribal SCs functioning in Rent Free Panchayat/ Vol. Society Buildings",
            "SC_T_BUC": "Tribal SCs Buildings Under Construction",
            "SC_T_BRC": "Tribal SCs Buildings required to be constructed",
    
            "PHC_T_GB": "Tribal PHCs functioning in Govt. Buildings",
            "PHC_T_RB": "Tribal PHCs functioning in Rented Buildings",
            "PHC_T_RFP": "Tribal PHCs functioning in Rent Free Panchayat/ Vol. Society Buildings",
            "PHC_T_BUC": "Tribal PHCs Buildings Under Construction",
            "PHC_T_BRC": "Tribal PHCs Buildings required to be constructed",
    
            "CHC_T_GB": "Tribal CHCs functioning in Govt. Buildings",
            "CHC_T_RB": "Tribal CHCs functioning in Rented Buildings",
            "CHC_T_RFP": "Tribal CHCs functioning in Rent Free Panchayat/ Vol. Society Buildings",
            "CHC_T_BUC": "Tribal CHCs functioning in Buildings Under Construction",
            "CHC_T_BRC": "Tribal CHCs functioning in Buildings required to be constructed",
    
            "HWF_ANM_SC_T_R" : "Required Health worker Female at Tribal SCs",
            "HWF_ANM_SC_T_S" : "Sanctioned Health worker Female at Tribal SCs",
            "HWF_ANM_SC_T_P" : "In position Health worker Female at Tribal SCs",
            "HWF_ANM_SC_T_V" : "Vacant Health worker Female at Tribal SCs",
            "HWF_ANM_SC_T_SH" : "Shortfall Health worker Female at Tribal SCs",

            "HWF_ANM_SC_PHC_T_R" : "Required Health worker Female at Tribal SCs and PHCs",
            "HWF_ANM_SC_PHC_T_S" : "Sanctioned Health worker Female at Tribal SCs and PHCs",
            "HWF_ANM_SC_PHC_T_P" : "In position Health worker Female at Tribal SCs and PHCs",
            "HWF_ANM_SC_PHC_T_V" : "Vacant Health worker Female at Tribal SCs and PHCs",
            "HWF_ANM_SC_PHC_T_SH" : "Shortfall Health worker Female at Tribal SCs and PHCs",
    
            "HWM_ANM_SC_T_R" : "Required Health worker Male at Tribal SCs",
            "HWM_ANM_SC_T_S" : "Sanctioned Health worker Male at Tribal SCs",
            "HWM_ANM_SC_T_P" : "In position Health worker Male at Tribal SCs",
            "HWM_ANM_SC_T_V" : "Vacant Health worker Male at Tribal SCs",
            "HWM_ANM_SC_T_SH" : "Shortfall Health worker Male at Tribal SCs",
    
            "HAF_LHV_PHC_T_R" : "Required Health Assistants female LHV at Tribal PHCs",
            "HAF_LHV_PHC_T_S" : "Sanctioned Health Assistants female LHV at Tribal PHCs",
            "HAF_LHV_PHC_T_P" : "In position Health Assistants female LHV at Tribal PHCs",
            "HAF_LHV_PHC_T_V" : "Vacant Health Assistants female LHV at Tribal PHCs",
            "HAF_LHV_PHC_T_SH" : "Shortfall Health Assistants female LHV at Tribal PHCs",
    
            "HAM_PHC_T_R" : "Required Health Assistants Male at Tribal PHCs",
            "HAM_PHC_T_S" : "Sanctioned Health Assistants Male at Tribal PHCs",
            "HAM_PHC_T_P" : "In position Health Assistants Male at Tribal PHCs",
            "HAM_PHC_T_V" : "Vacant Health Assistants Male at Tribal PHCs",
            "HAM_PHC_T_SH" : "Shortfall Health Assistants Male at Tribal PHCs",
    
            "DOC_PHC_T_R" : "Required Doctors at Tribal PHCs",
            "DOC_PHC_T_S" : "Sanctioned Doctors at Tribal PHCs",
            "DOC_PHC_T_P" : "In Position Doctors at Tribal PHCs",
            "DOC_PHC_T_V" : "Vacant Doctors at Tribal PHCs",
            "DOC_PHC_T_SH" : "Shortfall Doctors at Tribal PHCs",
    
            "SUR_CHC_T_R": "Required Surgeons at Tribal CHCs",
            "SUR_CHC_T_S": "Sanctioned Surgeons at Tribal CHCs",
            "SUR_CHC_T_P": "In position Surgeons at Tribal CHCs",
            "SUR_CHC_T_V": "Vacant Surgeons at Tribal CHCs",
            "SUR_CHC_T_SH": "Shorfall Surgeons at Tribal CHCs",
    
            "OBGY_CHC_T_R": "Required OBGYs at Tribal CHCs",
            "OBGY_CHC_T_S": "Sanctioned OBGYs at Tribal CHCs",
            "OBGY_CHC_T_P": "In position OBGYs at Tribal CHCs",
            "OBGY_CHC_T_V": "Vacant OBGYs at Tribal CHCs",
            "OBGY_CHC_T_SH": "Shortfall OBGYs at Tribal CHCs",
    
            "PHY_CHC_T_R" : "Required Physicians at Tribal CHCs",
            "PHY_CHC_T_S" : "Sanctioned Physicians at Tribal CHCs",
            "PHY_CHC_T_P" : "In position Physicians at Tribal CHCs",
            "PHY_CHC_T_V" : "Vacant Physicians at Tribal CHCs",
            "PHY_CHC_T_SH" : "Shortfall Physicians at Tribal CHCs",
    
            "PAED_CHC_T_R": "Required Paediatricians at Tribal CHCs",
            "PAED_CHC_T_S": "Sanctioned Paediatricians at Tribal CHCs",
            "PAED_CHC_T_P": "In position Paediatricians at Tribal CHCs",
            "PAED_CHC_T_V": "Vacant Paediatricians at Tribal CHCs",
            "PAED_CHC_T_SH": "Shortfall Paediatricians at Tribal CHCs",
    
            "TSP_CHC_T_R": "Required total specialists at Tribal CHCs",
            "TSP_CHC_T_S": "Sanctioned total specialists at Tribal CHCs",
            "TSP_CHC_T_P": "In position total specialists at Tribal CHCs",
            "TSP_CHC_T_V": "Vacant total specialists at Tribal CHCs",
            "TSP_CHC_T_SH": "Shortfall total specialists at Tribal CHCs",
    
            "RAD_CHC_T_R": "Required Radiographers at Tribal CHCs",
            "RAD_CHC_T_S": "Sanctioned Radiographers at Tribal CHCs",
            "RAD_CHC_T_P": "In position Radiographers at Tribal CHCs",
            "RAD_CHC_T_V": "Vacant Radiographers at Tribal CHCs",
            "RAD_CHC_T_SH": "Shortfall Radiographers at Tribal CHCs",
    
            "PHARMA_PHC_CHC_T_R": "Required Pharmacists at Tribal PHCs and CHCs",
            "PHARMA_PHC_CHC_T_S": "Sanctioned Pharmacists at Tribal PHCs and CHCs ",
            "PHARMA_PHC_CHC_T_P": "In Position Pharmacists at Tribal PHCs and CHCs",
            "PHARMA_PHC_CHC_T_V": "Vacant Pharmacists at Tribal PHCs and CHCs",
            "PHARMA_PHC_CHC_T_SH": "Shortfall Pharmacists at Tribal PHCs and CHCs",
    
            
            "LT_PHC_CHC_T_R": "Required Lab technicians at Tribal PHCs and CHCs",
            "LT_PHC_CHC_T_S": "Sanctioned Lab technicians at Tribal PHCs and CHCs",
            "LT_PHC_CHC_T_P": "In Position Lab technicians at Tribal PHCs and CHCs",
            "LT_PHC_CHC_T_V": "Vacant Lab technicians at rural PHCs and CHCs",
            "LT_PHC_CHC_T_SH": "Shortfall Lab technicians at Tribal PHCs and CHCs",
    
            "NURSE_PHC_CHC_T_R" : "Required nursing staff at Tribal PHCs and CHCs",
            "NURSE_PHC_CHC_T_S" : "Sanctioned nursing staff at Tribal PHCs and CHCs",
            "NURSE_PHC_CHC_T_P" : "In Position nursing staff at Tribal PHCs and CHCs",
            "NURSE_PHC_CHC_T_V" : "Vacant nursing staff at Tribal PHCs and CHCs",
            "NURSE_PHC_CHC_T_SH" : "Shortfall nursing staff at Tribal PHCs and CHCs",
    

}

# %%
len(features_2013)
# Out:
# 372

# %%
import pandas as pd
import openpyxl
pd.set_option('display.precision',10)
import re
remove_char = lambda x : re.sub('[*#+^@$"\n\r]', '', str(x))

# %%
xls_names = [
    'rhs_13_tables-converted (1).xlsx',
    ]

# %%
dirname = '/home/suraj/RHS/rhs 13/'

# %%
df_all_1 = pd.DataFrame()
initial_state_row = False
frames = []
frames_sheet = []
for xls in xls_names:
    df = pd.read_excel(open(dirname+xls, 'rb'),index_col=None,header=None,sheet_name=None)
    print(df.keys())
    df_sheets_all = pd.DataFrame()
    frames_sheet = []
    for x in df.keys():
        df_sheet = pd.read_excel(open(dirname+xls, 'rb'),index_col=None,header=None,sheet_name=x)
        print(x)
        index = range(1, len(df_sheet) + 1)
        df_sheet.index = index
        if len(df_sheet.columns) != 0:
            if (xls == xls_names[0] and x == "Table 46") or (xls == xls_names[0] and x == "Table 47") or (xls == xls_names[0] and x == "Table 48"):
                ur_row = df_sheet.loc[df_sheet[3] == 'Lakshadweep'].index.tolist()
                if len(ur_row) != 0:
                    print("Inside lakshwadeep")
#                     if( x == 'Table 41.'):
#                         df_sheet = df_sheet.drop(df_sheet.index[:ur_row[0]-5])
#                     else:
                    df_sheet = df_sheet.drop(df_sheet.index[:ur_row[0]-1])
                    df_sheet = df_sheet.reset_index(drop=True)
                    frames_sheet.append(df_sheet)
                    continue
                else:
                    print("Lakshadweep Skipped.")
            
            df_sheet=df_sheet.replace('#','',regex=True).astype(str)
            ur_row = df_sheet.loc[df_sheet[2] == 'Gujarat'].index.tolist()
            if len(ur_row) != 0:
                df_sheet = df_sheet.drop(df_sheet.index[:ur_row[0]-7])
                if initial_state_row:
                    df_sheet = df_sheet.drop([0,1],axis=1)
                initial_state_row = True
                df_sheet = df_sheet.reset_index(drop=True)
                frames_sheet.append(df_sheet)
            else:
                df_sheet=df_sheet.replace('#','',regex=True).astype(str)
                ur_row = df_sheet.loc[df_sheet[1] == 'Gujarat'].index.tolist()
                if len(ur_row) != 0:
                    df_sheet = df_sheet.drop(df_sheet.index[:ur_row[0]-7])
                    #print(df_sheet.head(0).columns)
                    #print(df_sheet[1])
                    if initial_state_row:
                        df_sheet = df_sheet.drop([0,1],axis=1)
                    initial_state_row = True
                    #df_sheet = df_sheet.drop([0,1],axis=1)
                    df_sheet = df_sheet.reset_index(drop=True)
                    frames_sheet.append(df_sheet)           
                else:
                    df_sheet=df_sheet.replace('#','',regex=True).astype(str)
                    ur_row = df_sheet.loc[df_sheet[3] == 'Gujarat'].index.tolist()
                    if len(ur_row) != 0:
                        df_sheet = df_sheet.drop(df_sheet.index[:ur_row[0]-7])
                        df_sheet = df_sheet.drop([2,3],axis=1)
                        df_sheet = df_sheet.reset_index(drop=True)
                        frames_sheet.append(df_sheet)
                    else:
                        df_sheet=df_sheet.replace('#','',regex=True).astype(str)
                        ur_row = df_sheet.loc[df_sheet[0] == 'Goa'].index.tolist()
                        if len(ur_row) != 0:
                            df_sheet = df_sheet.drop(df_sheet.index[:ur_row[0]-6])
                            df_sheet = df_sheet.drop([0],axis=1)
                            df_sheet = df_sheet.reset_index(drop=True)
                            frames_sheet.append(df_sheet)
                        else:
                            df_sheet=df_sheet.replace('#','',regex=True).astype(str)
                            ur_row = df_sheet.loc[df_sheet[1] == 'Karnataka'].index.tolist()
                            if len(ur_row) != 0:
                                df_sheet = df_sheet.drop(df_sheet.index[:ur_row[0]-12])
                                df_sheet = df_sheet.drop([0,1],axis=1)
                                df_sheet = df_sheet.reset_index(drop=True)
                                frames_sheet.append(df_sheet)
                            else:
                                 print("Skipped sheet is {}".format(x))

            
    df_sheets_all = pd.concat(frames_sheet,axis=1,ignore_index=True)
    frames.append(df_sheets_all)
print(len(frames))
df_all_1 = pd.concat(frames,axis=1,ignore_index=True)
# Out:
# dict_keys(['Table 1', 'Table 2', 'Table 3', 'Table 4', 'Table 5', 'Table 6', 'Table 7', 'Table 8', 'Table 9', 'Table 10', 'Table 11', 'Table 12', 'Table 13', 'Table 14', 'Table 15', 'Table 16', 'Table 17', 'Table 18', 'Table 19', 'Table 20', 'Table 21', 'Table 22', 'Table 23', 'Table 24', 'Table 25', 'Table 26', 'Table 27', 'Table 28', 'Table 29', 'Table 30', 'Table 31', 'Table 32', 'Table 33', 'Table 34', 'Table 35', 'Table 36', 'Table 37', 'Table 38', 'Table 39', 'Table 40', 'Table 41', 'Table 42', 'Table 43', 'Table 44', 'Table 45', 'Table 46', 'Table 47', 'Table 48', 'Table 49', 'Table 50', 'Table 51', 'Table 52', 'Table 53', 'Table 54', 'Table 55', 'Table 56', 'Table 57', 'Table 58', 'Table 59', 'Table 60', 'Table 61', 'Table 62', 'Table 63', 'Table 64', 'Table 65', 'Table 66', 'Table 67', 'Table 68', 'Table 69', 'Table 70', 'Table 71', 'Table 72', 'Table 73'])
# Table 1
# Table 2
# Table 3
# Table 4
# Table 5
# Table 6
# Table 7
# Table 8
# Table 9
# Table 10
# Table 11
# ...

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
# len(df_all_1.columns)df_states = df_all_1[9]
# df_all_1.insert(0,column='A',value=df_states)
df_all_1.iloc[0]
import numpy as np
df_all_1.replace('nan', np.nan, inplace=True)
df_all_1 = df_all_1.dropna(how='all', axis=1)
df_all_1.iloc[0]
# Out:
# 0                     1
# 1        Andhra Pradesh
# 2             270297.74
# 3               4747.26
# 4                275045
# 5                 98.27
# 6                    23
# 7                 27800
# 9              55401067
# 10             20808940
# 11             76210007
# 12                 72.7
# 13             56361702
# 14             28219075
# 15             84580777
# 16                 66.6
# 17             84580777
# 18                   11
# 19                  308
# 21                 1.73
# 22                35.61
# 23                10.98
# 24                  204
# 25                 4383
# 26                  277
# 27                 17.5
# 28                 17.9
# 29                 16.6
# 30                  7.4
# 31                  8.4
# 32                  5.1
# 33                   41
# 34                   46
# 35                   30
# 36                 6129
# 37                 7894
# 38                10568
# 39                10568
# ...

# %%
columns_delete = [17,66,81,88,94,118,139,212,218,225,233,245,250,259,275,280,285,306,307,320,330,337,343,379,419]

# %%
print(len(columns_delete))
print(len(df_all_1.columns))
# Out:
# 25
# 397

# %%
import numpy as np
df_all_1.replace('nan', np.nan, inplace=True)
df_all_1 = df_all_1.dropna(axis=1, how='all')
# df_all_1

# %%
df_all_1 = df_all_1.drop(columns_delete,axis=1)
df_all_1 = df_all_1.drop(df_all_1.index[36:53])

# %%
df_all_1.replace('N App', np.nan, inplace=True)
df_all_1.replace('**', np.nan, inplace=True)
df_all_1.replace('*', np.nan, inplace=True)
df_all_1.replace('NaN', np.nan, inplace=True)
df_all_1.replace('NA', np.nan, inplace=True)

df_all_1 = df_all_1.dropna(axis=1, how='all')

print(len(df_all_1.columns))
# Out:
# 372

# %%
df_all_1.columns = features_2013
len(df_all_1.columns)
# Out:
# 372

# %%
df_all_1
# Out:
#    S.NO                 ST          AR        AU      ATT    P_R  N_D     N_V  \
# 0     1     Andhra Pradesh   270297.74   4747.26   275045  98.27   23   27800
# 1     2  Arunachal Pradesh         NaN       NaN    83743    NaN   17    5589
# 2     3              Assam    77476.23    961.77    78438  98.77   27   26395
# 3     4              Bihar     92358.4    1804.6    94163  98.08   38   44874
# 4     5       Chhattisgarh   133325.25   1865.75   135191  98.62   27   20126
# 5     6                Goa     3190.33    511.67     3702  86.18    2     334
# 6     7            Gujarat    190796.5    5227.5   196024  97.33   26   18225
# 7     8            Haryana    42931.63   1280.37    44212   97.1   21    6841
# 8     9   Himachal Pradesh    55431.29    241.71    55673  99.57   12   20690
# 9    10    Jammu & Kashmir    221285.9     950.1   222236  99.57   22    6551
# 10   11          Jharkhand    77921.57   1792.43    79714  97.75   24   32394
# ...

# %%
df_all_1.to_excel( r'/home/suraj/RHS/rhs 13/RHS_Combined_2013.xlsx',
                  sheet_name= '2013'
                )

# %%
df_all_1.to_csv("/home/suraj/RHS/rhs 13/RHS_Combined_2013.csv", encoding='utf-8', index=False)
